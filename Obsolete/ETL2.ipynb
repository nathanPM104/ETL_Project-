# %%
import pandas as pd
from sqlalchemy import create_engine
#import psycopg2
from config import password

# %% [markdown]
# #### Eliza's Section

# %% [markdown]
# #### Lora's Section

# %%
#load in coffee data and create pandas datafile
coffee_file = "Resources/domestic-consumption.csv"
coffee_df = pd.read_csv(coffee_file)
coffee_df.head(10)
# Out:
#                domestic_consumption    1990    1991    1992     1993  \
# 0                            Angola    20.0    30.0    35.0    20.00
# 1  Bolivia (Plurinational State of)    25.0    27.0    27.5    28.50
# 2                            Brazil  8200.0  8500.0  8900.0  9100.00
# 3                           Burundi     2.0     1.6     1.7     1.91
# 4                           Ecuador   350.0   350.0   350.0   350.00
# 5                         Indonesia  1242.0  1280.0  1319.0  1359.00
# 6                        Madagascar   350.0   300.0   350.0   360.00
# 7                            Malawi     2.0     2.0     2.0     2.00
# 8                  Papua New Guinea     3.0     3.0     3.0     2.00
# 9                          Paraguay    15.0    15.0    15.0    20.00
#
#        1994     1995     1996     1997     1998  ...       2009      2010  \
# 0    25.000     10.0     20.0     40.0     30.0  ...     30.000     30.00
# ...

# %%
coffee_df_2016 = coffee_df[['domestic_consumption', '2016']].copy()
coffee_df_2016.head()
# Out:
#                domestic_consumption     2016
# 0                            Angola     30.0
# 1  Bolivia (Plurinational State of)     57.0
# 2                            Brazil  21225.0
# 3                           Burundi      2.0
# 4                           Ecuador    155.0

# %%
coffee_df_2016.rename(columns={"domestic_consumption" : "country", "2016" : "coffee_consumption"}, inplace=True)
coffee_df_2016.head()
# Out:
#                             country  coffee_consumption
# 0                            Angola                30.0
# 1  Bolivia (Plurinational State of)                57.0
# 2                            Brazil             21225.0
# 3                           Burundi                 2.0
# 4                           Ecuador               155.0

# %%
conn = f'postgresql://postgres:{password}@localhost:5432/ETL'

# %%
engine = create_engine(conn, echo=True)
sqlite_connection = engine.connect()
# Out:
# 2021-06-12 11:58:10,136 INFO sqlalchemy.engine.base.Engine select version()
# 2021-06-12 11:58:10,136 INFO sqlalchemy.engine.base.Engine {}
# 2021-06-12 11:58:10,137 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2021-06-12 11:58:10,138 INFO sqlalchemy.engine.base.Engine {}
# 2021-06-12 11:58:10,139 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-06-12 11:58:10,140 INFO sqlalchemy.engine.base.Engine {}
# 2021-06-12 11:58:10,141 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-06-12 11:58:10,142 INFO sqlalchemy.engine.base.Engine {}
# 2021-06-12 11:58:10,143 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2021-06-12 11:58:10,143 INFO sqlalchemy.engine.base.Engine {}

# %%
engine.table_names()
# Out:
# 2021-06-12 11:58:12,317 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2021-06-12 11:58:12,318 INFO sqlalchemy.engine.base.Engine {'schema': 'public'}
# ['coffee_df_2016', 'happinessalcohol_df']

# %%
coffee_df_2016.to_sql('coffee_df_2016', con=engine, if_exists='append', index=False)
# Out:
# 2021-06-12 11:58:13,944 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-06-12 11:58:13,945 INFO sqlalchemy.engine.base.Engine {'name': 'coffee_df_2016'}
# 2021-06-12 11:58:13,947 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-06-12 11:58:13,949 INFO sqlalchemy.engine.base.Engine INSERT INTO coffee_df_2016 (country, coffee_consumption) VALUES (%(country)s, %(coffee_consumption)s)
# ...

# %%
#load in happy and beers data and create pandas datafile
HappinessAlcohol_file = "Resources/HappinessAlcoholConsumption.csv"
HappinessAlcohol_df = pd.read_csv(HappinessAlcohol_file)
HappinessAlcohol_df.head()
# Out:
#        Country          Region Hemisphere  HappinessScore  HDI  GDP_PerCapita  \
# 0      Denmark  Western Europe      north           7.526  928         53.579
# 1  Switzerland  Western Europe      north           7.509  943         79.866
# 2      Iceland  Western Europe      north           7.501  933         60.530
# 3       Norway  Western Europe      north           7.498  951         70.890
# 4      Finland  Western Europe      north           7.413  918         43.433
#
#    Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita
# 0             224                81             278
# 1             185               100             280
# 2             233                61              78
# 3             169                71             129
# 4             263               133              97

# %% [markdown]
# #### Stephen's Section

# %% [markdown]
# #### Nathan's Section
